# %%
import gymnasium as gym
import matplotlib.pyplot as plt
import time
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv

env = gym.make('BipedalWalker-v3', render_mode='human')

def make_env():
    return gym.make('BipedalWalker-v3')

env = SubprocVecEnv([make_env for i in range(8)])

model = PPO(
    "MlpPolicy",
    env,
    device="cuda",
    n_steps=2048,
    batch_size=512,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    learning_rate=3e-4,
    clip_range=0.2,
    ent_coef=0.0,
    verbose=1,
)

model.learn(total_timesteps=100000)
env.close()
# Out:
# C:\Users\logan\PycharmProjects\BipedalWalker\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Using cuda device
# ...

# %%
import torch
print("Cuda device: ", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# Cuda device:  NVIDIA GeForce RTX 3070

# %%
import gymnasium as gym

env = gym.make('BipedalWalker-v3', render_mode='human')
obs, info = env.reset()


action, _ = model.predict(obs, deterministic=True)
obs, reward, terminated, truncated, info = env.step(action)

if terminated or truncated:
    obs, info = env.reset()
# Out:
# C:\Users\logan\PycharmProjects\BipedalWalker\.venv\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 env = gym.make('BipedalWalker-v3', render_mode='human')
#       4 obs, info = env.reset()
# ----> 7 action, _ = model.predict(obs, deterministic=True)
#       8 obs, reward, terminated, truncated, info = env.step(action)
#      10 if terminated or truncated:
#
# NameError: name 'model' is not defined

# %%
env.observation_space
env.action_space
# Out:
# Box(-1.0, 1.0, (4,), float32)

# %%
obs, reward, terminated, truncated, info = env.step(env.action_space.sample())
print(what_i_want_to_see)
# Out:
# (array([-0.03886872, -0.02788992, -0.00456976,  0.01327547,  0.42108116,
#        -0.4233424 ,  0.22067195,  0.6369167 ,  1.        ,  0.3466154 ,
#        -0.0502746 ,  0.19903404,  0.03339002,  1.        ,  0.4512243 ,
#         0.45634863,  0.47231975,  0.50111145,  0.5467162 ,  0.6166888 ,
#         0.7258962 ,  0.90685403,  1.        ,  1.        ], dtype=float32), np.float32(-0.14197433), False, False, {})

# %%
import pandas as pd
import numpy as np
OBS_COLUMNS = [
    "hull_angle",
    "hull_angular_velocity",
    "hull_velocity_x",
    "hull_velocity_y",

    "left_hip_angle",
    "left_hip_angular_velocity",
    "left_knee_angle",
    "left_knee_angular_velocity",

    "right_hip_angle",
    "right_hip_angular_velocity",
    "right_knee_angle",
    "right_knee_angular_velocity",

    *[f"lidar_{i}" for i in range(10)],

    "left_foot_contact",
    "right_foot_contact",
]

def obs_to_df(obs: np.ndarray) -> pd.DataFrame:
    return pd.DataFrame([obs], columns=OBS_COLUMNS)

# %%
df = obs_to_df(obs)
df["left_foot_contact"]
# Out:
# 0    1.0
# Name: left_foot_contact, dtype: float32
